# %%
""" Log
12/27/25 ---- Implemented AAA-greedy for Hubbard dimer of different sce/wce order.
Using the wce data up to t=1 and sce dat up to t=0.05 to construct the interpolation. 
"""
# Out:
# ' Log\n12/27/25 ---- Implemented AAA-greedy for Hubbard dimer of different sce/wce order.\nUsing the wce data up to t=1 and sce dat up to t=0.05 to construct the interpolation. \n'

# %%
### Using AAA to interpolate G(t, U=1.0, iw_n).
import sys
sys.path.append("../")
import numpy as np
import matplotlib.pyplot as plt
import sys, os
import analytic_solution as AS
import diff_G as diff
import utilities as ut
from adapol import anacont
from _bary_rational import AAA_adding0
import greedy_interpolation as greedy

# %%
beta = 50.0
Ntau = 401
Ns = 2
Nw = 4*int(beta)
Mat_fre = (2*np.linspace(0, Nw-1, Nw)+1)*np.pi/beta

wn = np.append(-np.flip(Mat_fre),Mat_fre)   # w_n = (2n+1)*pi/beta

# %%
eta = 0
Nt = 101
T = 2
t_values_ED = np.linspace(0, T, Nt) +1j*eta
wce_order = 12
test_order = wce_order + 1
Gij_iwn_exact = np.zeros((len(t_values_ED), wn.size, Ns, Ns), dtype ='complex')
Gij_iwn_exact_real = np.zeros((len(t_values_ED), wn.size, Ns, Ns), dtype ='complex')
Gij_iwn_wce = np.zeros((test_order, len(t_values_ED), wn.size, Ns, Ns), dtype ='complex')
Gij_iwn_sce = np.zeros((test_order, len(t_values_ED), wn.size, Ns, Ns), dtype ='complex')
U = 1.0
for u in range(t_values_ED.size):
    # if np.abs(t_values_ED[u]) < 1e-10:
    #     Gij_iwn_exact[u] = AS.G_analytic(0, wn, U, beta)
    #     Gij_iwn_exact_real[u] = AS.G_analytic(0, wn, U, beta)
    # else:
    #     Gij_iwn_exact[u] = 1/t_values_ED[u]*AS.G_analytic_old(1/t_values_ED[u], wn/t_values_ED[u])
    #     Gij_iwn_exact_real[u] = 1/t_values_ED[u]*AS.G_analytic_old(1/t_values_ED[u], wn/t_values_ED[u])
    Gij_iwn_exact[u] = AS.G_analytic(t_values_ED[u], wn, U, beta)
    Gij_iwn_exact_real[u] = AS.G_analytic(t_values_ED[u], wn, U, beta)
    for order in range(test_order):
        Gij_iwn_wce[order, u] = diff.Gij_wce_series(order, t_values_ED[u],  U , wn)
        Gij_iwn_sce[order, u] = diff.Gij_sce_series(order, t_values_ED[u],  U , wn, beta)
# Out:
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:32: RuntimeWarning: divide by zero encountered in divide
#   G2[:,0,0] =  0.5*((-b1+6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)+ 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:32: RuntimeWarning: invalid value encountered in divide
#   G2[:,0,0] =  0.5*((-b1+6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)+ 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:33: RuntimeWarning: divide by zero encountered in divide
#   G2[:,0,1] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:33: RuntimeWarning: invalid value encountered in divide
#   G2[:,0,1] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:33: RuntimeWarning: invalid value encountered in subtract
#   G2[:,0,1] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:34: RuntimeWarning: divide by zero encountered in divide
#   G2[:,1,0] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:34: RuntimeWarning: invalid value encountered in divide
#   G2[:,1,0] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:34: RuntimeWarning: invalid value encountered in subtract
#   G2[:,1,0] =  0.5*((b1-6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)- 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:35: RuntimeWarning: divide by zero encountered in divide
#   G2[:,1,1] =  0.5*((-b1+6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)+ 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:35: RuntimeWarning: invalid value encountered in divide
#   G2[:,1,1] =  0.5*((-b1+6*t)/(64*(b1-2*t)**2*t**2)-(b2+6*t)/(64*(b2+2*t)**2*t**2)+1/(64*(b3-2*t)*t**2)+ 1/(64*(b4+2*t)*t**2))
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:45: RuntimeWarning: divide by zero encountered in divide
#   G4[:,0,0] = 0.5*((3*b1**2-20*b1*t+44*t**2)/(4096*(b1-2*t)**3*t**4) + (3*b2**2+20*b2*t+44*t**2)/(4096*(b2+2*t)**3*t**4)  + (10*t-3*b3)/(4096*(b3-2*t)**2*t**4) - (10*t+3*b4)/(4096*(b4+2*t)**2*t**4) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:45: RuntimeWarning: invalid value encountered in divide
#   G4[:,0,0] = 0.5*((3*b1**2-20*b1*t+44*t**2)/(4096*(b1-2*t)**3*t**4) + (3*b2**2+20*b2*t+44*t**2)/(4096*(b2+2*t)**3*t**4)  + (10*t-3*b3)/(4096*(b3-2*t)**2*t**4) - (10*t+3*b4)/(4096*(b4+2*t)**2*t**4) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:46: RuntimeWarning: divide by zero encountered in divide
#   G4[:,0,1] = 0.5*(-(3*b1**2-20*b1*t+44*t**2)/(4096*(b1-2*t)**3*t**4) + (3*b2**2+20*b2*t+44*t**2)/(4096*(b2+2*t)**3*t**4)  + (10*t-3*b3)/(4096*(b3-2*t)**2*t**4) + (10*t+3*b4)/(4096*(b4+2*t)**2*t**4) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:46: RuntimeWarning: invalid value encountered in divide
#   G4[:,0,1] = 0.5*(-(3*b1**2-20*b1*t+44*t**2)/(4096*(b1-2*t)**3*t**4) + (3*b2**2+20*b2*t+44*t**2)/(4096*(b2+2*t)**3*t**4)  + (10*t-3*b3)/(4096*(b3-2*t)**2*t**4) + (10*t+3*b4)/(4096*(b4+2*t)**2*t**4) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:46: RuntimeWarning: invalid value encountered in add
#   G4[:,0,1] = 0.5*(-(3*b1**2-20*b1*t+44*t**2)/(4096*(b1-2*t)**3*t**4) + (3*b2**2+20*b2*t+44*t**2)/(4096*(b2+2*t)**3*t**4)  + (10*t-3*b3)/(4096*(b3-2*t)**2*t**4) + (10*t+3*b4)/(4096*(b4+2*t)**2*t**4) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:59: RuntimeWarning: divide by zero encountered in divide
#   G6[:,0,0] = 0.5*(-(5*b1**3-42*b1**2*t+132*b1*t**2-168*t**3)/(131071*(b1-2*t)**4*t**6) - (5*b2**3+42*b2**2*t+132*b2*t**2+168*t**3)/(131072*(b2+2*t)**4*t**6)  + (44*t**2-28*b3*t+5*b3**2)/(131072*(b3-2*t)**3*t**6)+ (44*t**2+28*b4*t+5*b4**2)/(131072*(b4+2*t)**3*t**6) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:59: RuntimeWarning: invalid value encountered in divide
#   G6[:,0,0] = 0.5*(-(5*b1**3-42*b1**2*t+132*b1*t**2-168*t**3)/(131071*(b1-2*t)**4*t**6) - (5*b2**3+42*b2**2*t+132*b2*t**2+168*t**3)/(131072*(b2+2*t)**4*t**6)  + (44*t**2-28*b3*t+5*b3**2)/(131072*(b3-2*t)**3*t**6)+ (44*t**2+28*b4*t+5*b4**2)/(131072*(b4+2*t)**3*t**6) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:61: RuntimeWarning: divide by zero encountered in divide
#   G6[:,0,1] = 0.5*((5*b1**3-42*b1**2*t+132*b1*t**2-168*t**3)/(131071*(b1-2*t)**4*t**6) - (5*b2**3+42*b2**2*t+132*b2*t**2+168*t**3)/(131072*(b2+2*t)**4*t**6)  + (44*t**2-28*b3*t+5*b3**2)/(131072*(b3-2*t)**3*t**6)- (44*t**2+28*b4*t+5*b4**2)/(131072*(b4+2*t)**3*t**6) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:61: RuntimeWarning: invalid value encountered in divide
#   G6[:,0,1] = 0.5*((5*b1**3-42*b1**2*t+132*b1*t**2-168*t**3)/(131071*(b1-2*t)**4*t**6) - (5*b2**3+42*b2**2*t+132*b2*t**2+168*t**3)/(131072*(b2+2*t)**4*t**6)  + (44*t**2-28*b3*t+5*b3**2)/(131072*(b3-2*t)**3*t**6)- (44*t**2+28*b4*t+5*b4**2)/(131072*(b4+2*t)**3*t**6) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:61: RuntimeWarning: invalid value encountered in subtract
#   G6[:,0,1] = 0.5*((5*b1**3-42*b1**2*t+132*b1*t**2-168*t**3)/(131071*(b1-2*t)**4*t**6) - (5*b2**3+42*b2**2*t+132*b2*t**2+168*t**3)/(131072*(b2+2*t)**4*t**6)  + (44*t**2-28*b3*t+5*b3**2)/(131072*(b3-2*t)**3*t**6)- (44*t**2+28*b4*t+5*b4**2)/(131072*(b4+2*t)**3*t**6) )
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:72: RuntimeWarning: divide by zero encountered in divide
#   term1 = (35*iwn**4-220*iwn**3*t+610*iwn**2*t**2-956*iwn*t**3+787*t**4)/(33554432*(iwn-t)**5*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:72: RuntimeWarning: invalid value encountered in divide
#   term1 = (35*iwn**4-220*iwn**3*t+610*iwn**2*t**2-956*iwn*t**3+787*t**4)/(33554432*(iwn-t)**5*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:73: RuntimeWarning: divide by zero encountered in divide
#   term2 = (35*iwn**4+220*iwn**3*t+610*iwn**2*t**2+956*iwn*t**3+787*t**4)/(33554432*(iwn+t)**5*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:73: RuntimeWarning: invalid value encountered in divide
#   term2 = (35*iwn**4+220*iwn**3*t+610*iwn**2*t**2+956*iwn*t**3+787*t**4)/(33554432*(iwn+t)**5*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:74: RuntimeWarning: divide by zero encountered in divide
#   term3 = -(35*iwn**3-375*iwn**2*t+1385*iwn*t**2-1789*t**3)/(33554432*(iwn-3*t)**4*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:74: RuntimeWarning: invalid value encountered in divide
#   term3 = -(35*iwn**3-375*iwn**2*t+1385*iwn*t**2-1789*t**3)/(33554432*(iwn-3*t)**4*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:75: RuntimeWarning: divide by zero encountered in divide
#   term4 = -(35*iwn**3+375*iwn**2*t+1385*iwn*t**2+1789*t**3)/(33554432*(iwn+3*t)**4*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:75: RuntimeWarning: invalid value encountered in divide
#   term4 = -(35*iwn**3+375*iwn**2*t+1385*iwn*t**2+1789*t**3)/(33554432*(iwn+3*t)**4*t**8)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:78: RuntimeWarning: invalid value encountered in add
#   G8[:,0,1] = -term1 + term2 + term3 - term4
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:89: RuntimeWarning: divide by zero encountered in divide
#   term1 = -(63*iwn**5-455*iwn**4*t+1470*iwn**3*t**2-2790*iwn**2*t**3+3315*iwn*t**4-2115*t**5)/(1073741824*(iwn-t)**6*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:89: RuntimeWarning: invalid value encountered in divide
#   term1 = -(63*iwn**5-455*iwn**4*t+1470*iwn**3*t**2-2790*iwn**2*t**3+3315*iwn*t**4-2115*t**5)/(1073741824*(iwn-t)**6*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:90: RuntimeWarning: divide by zero encountered in divide
#   term2 = -(63*iwn**5+455*iwn**4*t+1470*iwn**3*t**2+2790*iwn**2*t**3+3315*iwn*t**4+2115*t**5)/(1073741824*(iwn+t)**6*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:90: RuntimeWarning: invalid value encountered in divide
#   term2 = -(63*iwn**5+455*iwn**4*t+1470*iwn**3*t**2+2790*iwn**2*t**3+3315*iwn*t**4+2115*t**5)/(1073741824*(iwn+t)**6*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:91: RuntimeWarning: divide by zero encountered in divide
#   term3 = (63*iwn**4-868*iwn**3*t+4578*iwn**2*t**2-11028*iwn*t**3+10343*t**4)/(1073741824*(iwn-3*t)**5*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:91: RuntimeWarning: invalid value encountered in divide
#   term3 = (63*iwn**4-868*iwn**3*t+4578*iwn**2*t**2-11028*iwn*t**3+10343*t**4)/(1073741824*(iwn-3*t)**5*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:92: RuntimeWarning: divide by zero encountered in divide
#   term4 = (63*iwn**4+868*iwn**3*t+4578*iwn**2*t**2+11028*iwn*t**3+10343*t**4)/(1073741824*(iwn+3*t)**5*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:92: RuntimeWarning: invalid value encountered in divide
#   term4 = (63*iwn**4+868*iwn**3*t+4578*iwn**2*t**2+11028*iwn*t**3+10343*t**4)/(1073741824*(iwn+3*t)**5*t**10)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:95: RuntimeWarning: invalid value encountered in add
#   G10[:,0,1] = -term1 + term2 + term3 - term4
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:106: RuntimeWarning: divide by zero encountered in divide
#   term1 = (231*iwn**6-1890*iwn**5*t+6993*iwn**4*t**2-15484*iwn**3*t**3+22617*iwn**2*t**4-21762*iwn*t**5+ 11343*t**6)/(68719476736*(iwn-t)**7*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:106: RuntimeWarning: invalid value encountered in divide
#   term1 = (231*iwn**6-1890*iwn**5*t+6993*iwn**4*t**2-15484*iwn**3*t**3+22617*iwn**2*t**4-21762*iwn*t**5+ 11343*t**6)/(68719476736*(iwn-t)**7*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:107: RuntimeWarning: divide by zero encountered in divide
#   term2 = (231*iwn**6+1890*iwn**5*t+6993*iwn**4*t**2+15484*iwn**3*t**3+22617*iwn**2*t**4+21762*iwn*t**5+ 11343*t**6)/(68719476736*(iwn+t)**7*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:107: RuntimeWarning: invalid value encountered in divide
#   term2 = (231*iwn**6+1890*iwn**5*t+6993*iwn**4*t**2+15484*iwn**3*t**3+22617*iwn**2*t**4+21762*iwn*t**5+ 11343*t**6)/(68719476736*(iwn+t)**7*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:108: RuntimeWarning: divide by zero encountered in divide
#   term3 = (-231*iwn**5+3885*iwn**4*t-26502*iwn**3*t**2+91994*iwn**2*t**3-163331*iwn*t**4+ 119561*t**5)/(68719476736*(iwn-3*t)**6*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:108: RuntimeWarning: invalid value encountered in divide
#   term3 = (-231*iwn**5+3885*iwn**4*t-26502*iwn**3*t**2+91994*iwn**2*t**3-163331*iwn*t**4+ 119561*t**5)/(68719476736*(iwn-3*t)**6*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:109: RuntimeWarning: divide by zero encountered in divide
#   term4 = (231*iwn**5+3885*iwn**4*t+26502*iwn**3*t**2+91994*iwn**2*t**3+163331*iwn*t**4+ 119561*t**5)/(68719476736*(iwn+3*t)**6*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:109: RuntimeWarning: invalid value encountered in divide
#   term4 = (231*iwn**5+3885*iwn**4*t+26502*iwn**3*t**2+91994*iwn**2*t**3+163331*iwn*t**4+ 119561*t**5)/(68719476736*(iwn+3*t)**6*t**12)
# /global/cfs/cdirs/m1027/Yuan/MBIT/hubbard_dimer/t_interpolation/../diff_G.py:112: RuntimeWarning: invalid value encountered in add
#   G12[:,0,1] = -term1 + term2 + term3 - term4

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=True, sharey=True)
(ax11, ax12), (ax21, ax22) = axes

# (1,1) — like your figure(1)
for i in range(wn.size):
    ax11.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].real, 'C0')
    ax11.plot(t_values_ED.real, Gij_iwn_wce[-1,:, i, 0, 0 ].real, 'C1--')
ax11.set_title(r'$Re[G_{00}(i\omega_n,U=%.1f, t)]$'%(U))
ax11.set_ylim([-1,2])
# (1,2) — like your figure(2)
for i in range(wn.size):
    ax12.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0,1 ].real, 'C0')
    ax12.plot(t_values_ED.real, Gij_iwn_wce[2,:, i, 0,1 ].real, 'C1--')
ax12.set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%(U))

# (2,1) — like your figure(3)
for i in range(wn.size):
    ax21.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].imag, 'C0')
    ax21.plot(t_values_ED.real, Gij_iwn_wce[-1,:, i, 0, 0 ].imag, 'C1--')
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%(U))

# (2,2) — like your figure(4)
for i in range(wn.size):
    ax22.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 1 ].imag, 'C0')
    ax22.plot(t_values_ED.real, Gij_iwn_wce[-1, :, i, 0, 1 ].imag, 'C1--')
ax22.set_xlabel(r'$t$')
ax22.set_title(r'$Im[G_{01}(i\omega_n,U=%.1f, t)]$'%(U))

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')

fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=True, sharey=True)
(ax11, ax12), (ax21, ax22) = axes

# (1,1) — like your figure(1)
for i in range(wn.size):
    ax11.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].real, 'C0')
    ax11.plot(t_values_ED.real, Gij_iwn_sce[-1,:, i, 0, 0 ].real, 'C1--')
ax11.set_title(r'$Re[G_{00}(i\omega_n,U=%.1f, t)]$'%(U))
ax11.set_ylim([-1,2])
# (1,2) — like your figure(2)
for i in range(wn.size):
    ax12.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0,1 ].real, 'C0')
    ax12.plot(t_values_ED.real, Gij_iwn_sce[-1,:, i, 0,1 ].real, 'C1--')
ax12.set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%(U))

# (2,1) — like your figure(3)
for i in range(wn.size):
    ax21.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].imag, 'C0')
    ax21.plot(t_values_ED.real, Gij_iwn_sce[-1,:, i, 0, 0 ].imag, 'C1--')
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%(U))

# (2,2) — like your figure(4)
for i in range(wn.size):
    ax22.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 1 ].imag, 'C0')
    ax22.plot(t_values_ED.real, Gij_iwn_sce[-1, :, i, 0, 1 ].imag, 'C1--')
ax22.set_xlabel(r'$t$')
ax22.set_title(r'$Im[G_{01}(i\omega_n,U=%.1f, t)]$'%(U))

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')

fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=False, sharey=False)
(ax11, ax12), (ax21, ax22) = axes
wn_id=[Nw, Nw-1, Nw-2, Nw-3, Nw-4, Nw-10]
sce_order = 12
# (1,1) — like your figure(1)
for i in wn_id:
    ax11.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].real, 'C0')
    ax11.plot(t_values_ED.real, Gij_iwn_sce[sce_order,:, i, 0, 0 ].real, 'C1--')
ax11.set_title(r'$Re[G_{00}(i\omega_n,U=%.1f, t)], sce-order=%d$'%(U, sce_order))
ax11.set_ylim([-0.2,0.2])
# (1,2) — like your figure(2)
for i in wn_id:
    ax12.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0,1 ].real, 'C0')
    ax12.plot(t_values_ED.real, Gij_iwn_sce[sce_order,:, i, 0,1 ].real, 'C1--')
ax12.set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)], sce-order=%d$'%(U, sce_order))
ax12.set_ylim([-2,2])
ax12.set_xlim([0,0.1])
# (2,1) — like your figure(3)
for i in wn_id:
    ax21.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 0 ].imag, 'C0')
    ax21.plot(t_values_ED.real, Gij_iwn_sce[sce_order,:, i, 0, 0 ].imag, 'C1--')
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)], sce-order=%d$'%(U, sce_order))
ax21.set_ylim([-2,2])
ax21.set_xlim([0,2])

# (2,2) — like your figure(4)
for i in wn_id:
    ax22.plot(t_values_ED.real, Gij_iwn_exact[:, i, 0, 1 ].imag, 'C0')
    ax22.plot(t_values_ED.real, Gij_iwn_sce[sce_order, :, i, 0, 1 ].imag, 'C1--')
ax22.set_xlabel(r'$t$')
ax22.set_title(r'$Im[G_{01}(i\omega_n,U=%.1f, t)], sce-order=%d$'%(U, sce_order))

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')

fig.tight_layout()
plt.show()

# %%
err_bar = 1e-3
err_bar2 = 1e-1
wn_id = Nw
interp_order = 6
wce00_err = np.abs(Gij_iwn_exact[:, wn_id, 0,0]-Gij_iwn_wce[interp_order, :, wn_id, 0,0]) 
wce01_err = np.abs(Gij_iwn_exact[:, wn_id, 0,1]-Gij_iwn_wce[interp_order, :, wn_id, 0,1])
sce00_err = np.abs(Gij_iwn_exact[:, wn_id, 0,0]-Gij_iwn_sce[interp_order, :, wn_id, 0,0]) 
sce01_err = np.abs(Gij_iwn_exact[:, wn_id, 0,1]-Gij_iwn_sce[interp_order, :, wn_id, 0,1])

idx = np.where(wce00_err < err_bar)[0]
wce00_err_idx = idx[0]+1
idx = np.where(wce01_err < err_bar)[0]
if len(idx)==0:
    wce01_err_idx = 0
else:
    wce01_err_idx = idx[0]+1
idx = np.where(sce00_err > err_bar)[0]
sce00_err_idx = idx[0]+1
idx = np.where(sce01_err > err_bar)[0]
sce01_err_idx = idx[0]+1
print("t_values that wce/sce works for G00:", t_values_ED[wce00_err_idx], t_values_ED[sce00_err_idx])
print("t_values that wce/sce works for G01:", t_values_ED[wce01_err_idx], t_values_ED[sce01_err_idx] )


    
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=False, sharey=False)
(ax11, ax12), (ax21, ax22) = axes

# (1,2) — like your figure(2)
for i in range(wn.size):
    ax11.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, i, 0,1]-Gij_iwn_wce[interp_order, :, i, 0,1]), '--')
ax11.semilogy(t_values_ED.real, wce01_err, 'go', linewidth = 3)
ax11.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax11.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax11.scatter(t_values_ED[wce01_err_idx].real, wce01_err[wce01_err_idx], color='k', s=150)
ax11.set_xlim([0, 2])
ax11.set_ylim([1e-12, 1])
ax11.set_title(r'$Re[E_{01}(i\omega_n,U=%.1f, t)],wce-order= %d$'%(U, interp_order))

# (1,2) — like your figure(2)
for i in range(wn.size):
    ax12.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, i, 0,1]-Gij_iwn_sce[interp_order, :, i, 0,1]), '--')
ax12.semilogy(t_values_ED.real, sce01_err, 'ro', linewidth = 3)
ax12.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax12.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax12.scatter(t_values_ED[sce01_err_idx].real, sce01_err[sce01_err_idx], color='k', s=150)
ax12.set_xlim([0, 0.4])
ax12.set_title(r'$Re[E_{01}(i\omega_n,U=%.1f, t)],sce-order=%d$'%(U, interp_order))
# ax12.set_ylim(1e-10,1)

# (2,1) — like your figure(3)
for i in range(wn.size):
    ax21.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, i, 0,0]-Gij_iwn_wce[interp_order,:, i, 0,0]), '--')
ax21.semilogy(t_values_ED.real, wce00_err, 'go', linewidth = 3)
ax21.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax21.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax21.scatter(t_values_ED[wce00_err_idx].real, wce00_err[wce00_err_idx], color='k', s=150)
ax21.set_xlim([0, 2])
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[E_{00}(i\omega_n,U=%.1f, t)],wce-order=%d$'%(U, interp_order))

# (2,1) — like your figure(3)
for i in range(wn.size):
    ax22.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, i, 0,0]-Gij_iwn_sce[interp_order,:, i, 0,0]), '--')
ax22.semilogy(t_values_ED.real, sce00_err, 'ro', linewidth = 3)
ax22.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax22.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax22.scatter(t_values_ED[sce00_err_idx].real, sce00_err[sce00_err_idx], color='k', s=150)
ax22.set_xlabel(r'$t$')
ax22.set_xlim([0, 0.4])
ax22.set_title(r'$Im[E_{00}(i\omega_n,U=%.1f, t)],sce-order=%d$'%(U, interp_order))

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')

fig.tight_layout()
plt.show()
# Out:
# t_values that wce/sce works for G00: (0.64+0j) (0.14+0j)
# t_values that wce/sce works for G01: (0.72+0j) (0.08+0j)
# /global/common/software/nersc/pe/conda-envs/26.1.0/python-3.13/nersc-python/lib/python3.13/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /global/common/software/nersc/pe/conda-envs/26.1.0/python-3.13/nersc-python/lib/python3.13/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=False, sharey=False)
(ax11, ax12), (ax21, ax22) = axes

# (1,1) — like your figure(1)
# (1,2) — like your figure(2)
for i in range(test_order):
    ax11.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,1]-Gij_iwn_wce[i, :, Nw, 0,1]), '--', label = 'wce order= %d'%i)
ax11.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax11.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax11.set_title(r'$Re[E_{01}(i\omega_0,U=%.1f, t)]$'%U)
ax11.set_xlim([0, 2])
ax11.legend()

# (1,2) — like your figure(2)
for i in range(test_order):
    if np.mod(i,2)==1:
        ax12.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,1]-Gij_iwn_sce[i, :, Nw, 0,1]), label = 'sce order= %d'%i)
ax12.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax12.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax12.set_title(r'$Re[E_{01}(i\omega_0,U=%.1f, t)]$'%U)
ax12.set_xlim([0, 0.1])
ax12.set_ylim([1e-10, 1000])
ax12.legend()

# (2,1) — like your figure(3)
for i in range(test_order):
    ax21.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,0]-Gij_iwn_wce[i,:, Nw, 0,0]), '--', label = 'wce order= %d'%i)
ax21.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax21.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[E_{00}(i\omega_0,U=%.1f, t)]$'%U)
ax21.set_xlim([0, 2])
ax21.legend()
ax21.set_ylim([1e-6, 10])
for i in range(test_order):
        if np.mod(i,2)==0:
            ax22.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,0]-Gij_iwn_sce[i,:, Nw, 0,0]), label = 'sce order= %d'%i)
ax22.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax22.semilogy(t_values_ED.real, err_bar2+0*t_values_ED, 'k', linewidth = 3)
ax22.set_xlabel(r'$t$')
ax22.set_title(r'$Im[E_{00}(i\omega_0,U=%.1f, t)]$'%U)
ax22.set_xlim([0, 0.1])
ax22.legend()

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')
    

fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9), sharex=False, sharey=False)
(ax11, ax12), (ax21, ax22) = axes

# (1,1) — like your figure(1)
# (1,2) — like your figure(2)
order_up = 6
for i in range(order_up):
    # ax11.semilogy(t_values_ED.real, np.abs(Gij_iwn_wce[order_up, :, Nw, 0,1]-Gij_iwn_wce[i, :, Nw, 0,1]), '--', label = 'wce order= %d-%d'%(order_up,i))
    ax11.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,1]-Gij_iwn_wce[i, :, Nw, 0,1]), label = 'exact, wce order= %d'%i)
ax11.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax11.set_title(r'$Re[E_{01}(i\omega_0,U=%.1f, t)]$'%U)
ax11.set_xlim([0, T])
ax11.legend()

# (1,2) — like your figure(2)
for i in range(order_up):
    # ax12.semilogy(t_values_ED.real, np.abs(Gij_iwn_sce[order_up, :, Nw, 0,1]-Gij_iwn_sce[i, :, Nw, 0,1]), '--', label = 'sce order= %d-%d'%(order_up,i))
    ax12.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,1]-Gij_iwn_sce[i, :, Nw, 0,1]), label = 'exact, sce order= %d'%i)
ax12.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax12.set_title(r'$Re[E_{01}(i\omega_0,U=%.1f, t)]$'%U)
ax12.set_xlim([0, 0.2])
ax12.set_ylim([1e-10, 1000])
ax12.legend()

# (2,1) — like your figure(3)
for i in range(order_up):
    # ax21.semilogy(t_values_ED.real, np.abs(Gij_iwn_wce[order_up,:, Nw, 0,0]-Gij_iwn_wce[i,:, Nw, 0,0]), '--', label = 'wce order= %d-%d'%(order_up,i))
    ax21.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,0]-Gij_iwn_wce[i, :, Nw, 0,0]), label = 'exact, wce order= %d'%i)
ax21.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax21.set_xlabel(r'$t$')
ax21.set_title(r'$Im[E_{00}(i\omega_0,U=%.1f, t)]$'%U)
ax21.set_xlim([0, T])
ax21.legend()
ax21.set_ylim([1e-6, 10])
for i in range(order_up):
    # ax22.semilogy(t_values_ED.real, np.abs(Gij_iwn_sce[order_up,:, Nw, 0,0]-Gij_iwn_sce[i,:, Nw, 0,0]), '--',label = 'sce order= %d-%d'%(order_up,i))
    ax22.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact[:, Nw, 0,0]-Gij_iwn_sce[i, :, Nw, 0,0]), label = 'exact, sce order= %d'%i)
ax22.semilogy(t_values_ED.real, err_bar+0*t_values_ED, 'k', linewidth = 3)
ax22.set_xlabel(r'$t$')
ax22.set_title(r'$Im[E_{00}(i\omega_0,U=%.1f, t)]$'%U)
ax22.set_ylim([1e-10, 1000])
ax22.set_xlim([0, 0.1])
ax22.legend()

# Optional: remove duplicate y-labels on the right column
for ax in (ax12, ax22):
    ax.set_ylabel('')
    

fig.tight_layout()
plt.show()

# %%
### Constructing the interpolation data 
Nt_wce = 501 
T_wce = 0.72
print("The wce time window is:", (T_wce, T))
t_wce = np.linspace(T_wce, T, Nt_wce)

G_wce = np.zeros((len(t_wce), wn.size, Ns, Ns), dtype ='complex')
for i in range(len(t_wce)):
    G_wce[i] = diff.Gij_wce_series(interp_order, t_wce[i],  U , wn)

Nt_sce = 105
T_sce = 0.08
print("The sce time window is:", (0, T_sce))
t_sce = np.linspace(0, T_sce, Nt_sce)

G_sce = np.zeros((len(t_sce), wn.size, Ns, Ns), dtype ='complex')
for i in range(len(t_sce)):
    G_sce[i] = diff.Gij_sce_series(interp_order, t_sce[i],  U , wn, beta)
print(t_sce)
t_app = np.concatenate([t_sce, t_wce], axis=0)
G_app = np.concatenate([G_sce, G_wce], axis=0)
print(t_app.shape)
print(G_app.shape)

plt.figure(1)
for n in range(Nw):
    plt.plot(t_sce, G_sce[:, n, 0, 0].imag ,'C0')
    plt.plot(t_wce, G_wce[:, n, 0, 0].imag, 'C0')
    plt.plot(t_values_ED.real, Gij_iwn_exact[:, n, 0,0].imag, 'C1--')

plt.figure(2)
for n in range(Nw):
    plt.plot(t_sce, G_sce[:, n, 0, 1].real ,'C0')
    plt.plot(t_wce, G_wce[:, n, 0, 1].real, 'C0')
    plt.plot(t_values_ED.real, Gij_iwn_exact[:, n, 0,1].real, 'C1--')
# Out:
# The wce time window is: (0.72, 2)
# The sce time window is: (0, 0.08)
# [0.         0.00076923 0.00153846 0.00230769 0.00307692 0.00384615
#  0.00461538 0.00538462 0.00615385 0.00692308 0.00769231 0.00846154
#  0.00923077 0.01       0.01076923 0.01153846 0.01230769 0.01307692
#  0.01384615 0.01461538 0.01538462 0.01615385 0.01692308 0.01769231
#  0.01846154 0.01923077 0.02       0.02076923 0.02153846 0.02230769
#  0.02307692 0.02384615 0.02461538 0.02538462 0.02615385 0.02692308
#  0.02769231 0.02846154 0.02923077 0.03       0.03076923 0.03153846
#  0.03230769 0.03307692 0.03384615 0.03461538 0.03538462 0.03615385
#  0.03692308 0.03769231 0.03846154 0.03923077 0.04       0.04076923
#  0.04153846 0.04230769 0.04307692 0.04384615 0.04461538 0.04538462
#  0.04615385 0.04692308 0.04769231 0.04846154 0.04923077 0.05
#  0.05076923 0.05153846 0.05230769 0.05307692 0.05384615 0.05461538
#  0.05538462 0.05615385 0.05692308 0.05769231 0.05846154 0.05923077
#  0.06       0.06076923 0.06153846 0.06230769 0.06307692 0.06384615
#  0.06461538 0.06538462 0.06615385 0.06692308 0.06769231 0.06846154
#  0.06923077 0.07       0.07076923 0.07153846 0.07230769 0.07307692
#  0.07384615 0.07461538 0.07538462 0.07615385 0.07692308 0.07769231
#  0.07846154 0.07923077 0.08      ]
# (606,)
# (606, 400, 2, 2)

# %%
### AAA interpolation 
err_bar1 = 1e-2
G01_interp = np.zeros((t_values_ED.size, wn.size), dtype = complex)
G00_interp = np.zeros((t_values_ED.size, wn.size), dtype = complex)

for n in range(wn.size):
    print("n=", n)
    # G00_interp_temp = greedy.G_interp_v2(G_sce[:, n, 0, 0].imag, t_sce, G_wce[:, n, 0, 0].imag, t_wce, t_values_ED.real,  err=err_bar1, max_terms= 40)
    # G00_interp[:, n] = 1j*G00_interp_temp
    # G01_interp[:, n] = greedy.G_interp_v2(G_sce[:, n, 0, 1].real, t_sce, G_wce[:, n, 0,1].real, t_wce, t_values_ED.real,  err=err_bar1, max_terms= 40)
    r00 = AAA_adding0(t_app, G_app[:, n, 0,0].imag, rtol=err_bar1, max_terms= 40)
    G00_interp[:, n] = 1j*r00(t_values_ED.real)
    r01 = AAA_adding0(t_app, G_app[:, n, 0,1].real, rtol=err_bar1, max_terms= 40)
    G01_interp[:, n] = r01(t_values_ED.real)
# Out:
# n= 0
# closest pole to real axis: 25.2461975237689
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 1
# closest pole to real axis: 25.12100752558248
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 2
# closest pole to real axis: 24.99582105416153
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 3
# closest pole to real axis: 24.870638033161168
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 4
# closest pole to real axis: 24.745458396225118
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 5
# closest pole to real axis: 24.62028205205319
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 6
# closest pole to real axis: 24.495108928627065
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 7
# closest pole to real axis: 24.36993894431013
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 8
# closest pole to real axis: 24.24477199890277
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 9
# closest pole to real axis: 24.11960801229606
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 10
# closest pole to real axis: 23.994446889472595
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 11
# closest pole to real axis: 23.869288533669813
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 12
# closest pole to real axis: 23.744132853094126
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 13
# closest pole to real axis: 23.618979737699753
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 14
# closest pole to real axis: 23.493829090661126
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 15
# closest pole to real axis: 23.36868079489247
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 16
# closest pole to real axis: 23.243534747770205
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 17
# closest pole to real axis: 23.11839082412052
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 18
# closest pole to real axis: 22.993248908108143
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 19
# closest pole to real axis: 22.868108873647852
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 20
# closest pole to real axis: 22.7429705955975
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 21
# closest pole to real axis: 22.61783393543877
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 22
# closest pole to real axis: 22.492698762517588
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 23
# closest pole to real axis: 22.367564926130456
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 24
# closest pole to real axis: 22.24243227681319
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 25
# closest pole to real axis: 22.1173006690936
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 26
# closest pole to real axis: 21.992169942135465
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 27
# closest pole to real axis: 21.86703992763445
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 28
# closest pole to real axis: 21.74191045595569
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 29
# closest pole to real axis: 21.616781342081584
#
# closest pole to real axis: 1.4400581159630406
#
# n= 30
# closest pole to real axis: 21.4916524148475
#
# closest pole to real axis: 2.32654438045448
#
# n= 31
# closest pole to real axis: 21.36652347577744
#
# closest pole to real axis: 2.9414584443137364
#
# n= 32
# closest pole to real axis: 21.241394326962457
#
# closest pole to real axis: 3.434136767830813
#
# n= 33
# closest pole to real axis: 21.116264765546937
#
# closest pole to real axis: 3.8519571625859848
#
# n= 34
# closest pole to real axis: 20.991134571677378
#
# closest pole to real axis: 4.2173946781181195
#
# n= 35
# closest pole to real axis: 20.866003530736766
#
# closest pole to real axis: 4.543261257947291
#
# n= 36
# closest pole to real axis: 20.74087140689665
#
# closest pole to real axis: 4.837703633073977
#
# n= 37
# closest pole to real axis: 20.615737966911823
#
# closest pole to real axis: 5.106295899881388
#
# n= 38
# closest pole to real axis: 20.490602954058474
#
# closest pole to real axis: 5.353058733326027
#
# n= 39
# closest pole to real axis: 20.36546612019163
#
# closest pole to real axis: 5.581010564005701
#
# n= 40
# closest pole to real axis: 20.240327188404194
#
# closest pole to real axis: 5.792489563937006
#
# n= 41
# closest pole to real axis: 20.115185886366714
#
# closest pole to real axis: 5.98935329669576
#
# n= 42
# closest pole to real axis: 19.990041921317058
#
# closest pole to real axis: 6.173108549575553
#
# n= 43
# closest pole to real axis: 19.864894996384162
#
# closest pole to real axis: 6.344999077955476
#
# n= 44
# closest pole to real axis: 19.739744797166633
#
# closest pole to real axis: 6.5060668759676235
#
# n= 45
# closest pole to real axis: 19.614590999204218
#
# closest pole to real axis: 6.6571961371517645
#
# n= 46
# closest pole to real axis: 19.48943326474402
#
# closest pole to real axis: 6.758257863683417
#
# n= 47
# closest pole to real axis: 19.364271246757813
#
# closest pole to real axis: 6.893439213555331
#
# n= 48
# closest pole to real axis: 19.23910457507712
#
# closest pole to real axis: 7.0205457417410075
#
# n= 49
# closest pole to real axis: 19.113932875034596
#
# closest pole to real axis: 7.140098510704329
#
# n= 50
# closest pole to real axis: 18.988755753464236
#
# closest pole to real axis: 7.252558927613034
#
# n= 51
# closest pole to real axis: 18.863572799816698
#
# closest pole to real axis: 7.358338199922567
#
# n= 52
# closest pole to real axis: 18.738383588495154
#
# closest pole to real axis: 7.457804931958106
#
# n= 53
# closest pole to real axis: 18.61318767689303
#
# closest pole to real axis: 7.551291290499664
#
# n= 54
# closest pole to real axis: 18.487984604406222
#
# closest pole to real axis: 7.639098058488148
#
# n= 55
# closest pole to real axis: 18.362773894885315
#
# closest pole to real axis: 7.7214988128086475
#
# n= 56
# closest pole to real axis: 18.237555048594988
#
# closest pole to real axis: 7.798743402352756
#
# n= 57
# closest pole to real axis: 18.112327548578406
#
# closest pole to real axis: 7.871060873737573
#
# n= 58
# closest pole to real axis: 17.98709085831265
#
# closest pole to real axis: 7.9386619396507205
#
# n= 59
# closest pole to real axis: 17.86184441696973
#
# closest pole to real axis: 8.001741079568227
#
# n= 60
# closest pole to real axis: 17.736587641867132
#
# closest pole to real axis: 8.06047833728814
#
# n= 61
# closest pole to real axis: 17.611319929696947
#
# closest pole to real axis: 8.115040867981168
#
# n= 62
# closest pole to real axis: 17.486040649932903
#
# closest pole to real axis: 8.165584273844004
#
# n= 63
# closest pole to real axis: 17.360749147446292
#
# closest pole to real axis: 8.212253765872868
#
# n= 64
# closest pole to real axis: 17.235444742746044
#
# closest pole to real axis: 8.255185177848674
#
# n= 65
# closest pole to real axis: 17.110126726663193
#
# closest pole to real axis: 8.294505853903004
#
# n= 66
# closest pole to real axis: 16.984794361716986
#
# closest pole to real axis: 8.330335430273852
#
# n= 67
# closest pole to real axis: 16.85944688452693
#
# closest pole to real axis: 8.362786524956595
#
# n= 68
# closest pole to real axis: 16.734083495724835
#
# closest pole to real axis: 8.391965349567382
#
# n= 69
# closest pole to real axis: 16.60870336775248
#
# closest pole to real axis: 8.417972253153888
#
# n= 70
# closest pole to real axis: 16.48330563932174
#
# closest pole to real axis: 8.440902207161288
#
# n= 71
# closest pole to real axis: 16.35788941258549
#
# closest pole to real axis: 8.46084523877235
#
# n= 72
# closest pole to real axis: 16.232453756596858
#
# closest pole to real axis: 8.477886821632326
#
# n= 73
# closest pole to real axis: 16.106997701972258
#
# closest pole to real axis: 8.49210822542645
#
# n= 74
# closest pole to real axis: 15.981520240309015
#
# closest pole to real axis: 8.503586831760092
#
# n= 75
# closest pole to real axis: 15.856020324464975
#
# closest pole to real axis: 8.512396420622727
#
# n= 76
# closest pole to real axis: 15.730496863973503
#
# closest pole to real axis: 8.518607429184039
#
# n= 77
# closest pole to real axis: 15.604948727440373
#
# closest pole to real axis: 8.522287187583034
#
# n= 78
# closest pole to real axis: 15.47937473505292
#
# closest pole to real axis: 8.52350013286289
#
# n= 79
# closest pole to real axis: 15.353773663754854
#
# closest pole to real axis: 8.522308005340719
#
# n= 80
# closest pole to real axis: 15.228144241991197
#
# closest pole to real axis: 8.51877002727897
#
# n= 81
# closest pole to real axis: 15.1024851470785
#
# closest pole to real axis: 8.51294306676737
#
# n= 82
# closest pole to real axis: 14.976795004818237
#
# closest pole to real axis: 8.49247864502488
#
# n= 83
# closest pole to real axis: 14.85107238781052
#
# closest pole to real axis: 8.482590479652186
#
# n= 84
# closest pole to real axis: 14.725315813607688
#
# closest pole to real axis: 8.470560504418028
#
# n= 85
# closest pole to real axis: 14.599523741121581
#
# closest pole to real axis: 8.456437983904479
#
# n= 86
# closest pole to real axis: 14.473694572243803
#
# closest pole to real axis: 8.440270448332688
#
# n= 87
# closest pole to real axis: 14.347826646014259
#
# closest pole to real axis: 8.42210379599676
#
# n= 88
# closest pole to real axis: 14.221918238083544
#
# closest pole to real axis: 8.40198238900508
#
# n= 89
# closest pole to real axis: 14.095967560068534
#
# closest pole to real axis: 8.379949141781301
#
# n= 90
# closest pole to real axis: 13.969972755972108
#
# closest pole to real axis: 8.356045603458009
#
# n= 91
# closest pole to real axis: 13.843931900080824
#
# closest pole to real axis: 8.330312034721176
#
# n= 92
# closest pole to real axis: 13.717842996619128
#
# closest pole to real axis: 8.302787479607078
#
# n= 93
# closest pole to real axis: 13.591703976467699
#
# closest pole to real axis: 8.273509832768651
#
# n= 94
# closest pole to real axis: 13.465512694531311
#
# closest pole to real axis: 8.242515902140115
#
# n= 95
# closest pole to real axis: 13.33926692940072
#
# closest pole to real axis: 8.209841468035469
#
# n= 96
# closest pole to real axis: 13.212964381191899
#
# closest pole to real axis: 8.175521338765297
#
# n= 97
# closest pole to real axis: 13.086602669305618
#
# closest pole to real axis: 8.139589402721645
#
# n= 98
# closest pole to real axis: 12.960179330978951
#
# closest pole to real axis: 8.102078677627478
#
# n= 99
# closest pole to real axis: 12.833691819323391
#
# closest pole to real axis: 8.063021357139773
#
# n= 100
# closest pole to real axis: 12.707137503204171
#
# closest pole to real axis: 8.022448854991097
#
# n= 101
# closest pole to real axis: 12.580513664926384
#
# closest pole to real axis: 7.973194572722913
#
# n= 102
# closest pole to real axis: 12.453817499323419
#
# closest pole to real axis: 7.929888770975334
#
# n= 103
# closest pole to real axis: 12.32704611363946
#
# closest pole to real axis: 7.8851521271186185
#
# n= 104
# closest pole to real axis: 12.200196526641378
#
# closest pole to real axis: 7.839013497006911
#
# n= 105
# closest pole to real axis: 12.073265668264014
#
# closest pole to real axis: 7.791501139169997
#
# n= 106
# closest pole to real axis: 11.946250380518025
#
# closest pole to real axis: 7.742642748389067
#
# n= 107
# closest pole to real axis: 11.819147418063384
#
# closest pole to real axis: 7.692465487329583
#
# n= 108
# closest pole to real axis: 11.691953448639037
#
# closest pole to real axis: 7.640996017364049
#
# n= 109
# closest pole to real axis: 11.564665055856105
#
# closest pole to real axis: 7.588260528156159
#
# n= 110
# closest pole to real axis: 11.437278741161482
#
# closest pole to real axis: 7.534284766025162
#
# n= 111
# closest pole to real axis: 11.309790926813124
#
# closest pole to real axis: 7.479094061642277
#
# n= 112
# closest pole to real axis: 11.182197960133703
#
# closest pole to real axis: 7.4174749681812555
#
# n= 113
# closest pole to real axis: 11.054496118439635
#
# closest pole to real axis: 7.360081419341288
#
# n= 114
# closest pole to real axis: 10.926681614305599
#
# closest pole to real axis: 7.301542530731533
#
# n= 115
# closest pole to real axis: 10.79875060332324
#
# closest pole to real axis: 7.241882338003664
#
# n= 116
# closest pole to real axis: 10.670699192503026
#
# closest pole to real axis: 7.1811245837928475
#
# n= 117
# closest pole to real axis: 10.542523449211028
#
# closest pole to real axis: 7.119292741246024
#
# n= 118
# closest pole to real axis: 10.414219413110393
#
# closest pole to real axis: 7.056410037354734
#
# n= 119
# closest pole to real axis: 10.285783109330465
#
# closest pole to real axis: 6.992499475529235
#
# n= 120
# closest pole to real axis: 10.157210562776672
#
# closest pole to real axis: 6.927583858077902
#
# n= 121
# closest pole to real axis: 10.028497815998204
#
# closest pole to real axis: 6.857665258612372
#
# n= 122
# closest pole to real axis: 9.899640947966299
#
# closest pole to real axis: 6.790926514699263
#
# n= 123
# closest pole to real axis: 9.770636096424823
#
# closest pole to real axis: 6.72324680948235
#
# n= 124
# closest pole to real axis: 9.641479482529299
#
# closest pole to real axis: 6.65464843703863
#
# n= 125
# closest pole to real axis: 9.512167438632531
#
# closest pole to real axis: 6.585153593885391
#
# n= 126
# closest pole to real axis: 9.382696439343043
#
# closest pole to real axis: 6.51478439921762
#
# n= 127
# closest pole to real axis: 9.25306313614199
#
# closest pole to real axis: 6.440198240821038
#
# n= 128
# closest pole to real axis: 9.123264396062472
#
# closest pole to real axis: 6.368247416613136
#
# n= 129
# closest pole to real axis: 8.993297344321348
#
# closest pole to real axis: 6.295485443721316
#
# n= 130
# closest pole to real axis: 8.86315941120712
#
# closest pole to real axis: 6.221934393373947
#
# n= 131
# closest pole to real axis: 8.732848384597464
#
# closest pole to real axis: 6.147616351191633
#
# n= 132
# closest pole to real axis: 8.602362466443363
#
# closest pole to real axis: 6.06965564457239
#
# n= 133
# closest pole to real axis: 8.471700335428707
#
# closest pole to real axis: 5.993957540202597
#
# n= 134
# closest pole to real axis: 8.340861215082075
#
# closest pole to real axis: 5.917556377058531
#
# n= 135
# closest pole to real axis: 8.209844947735503
#
# closest pole to real axis: 5.840474515760099
#
# n= 136
# closest pole to real axis: 8.07865207485694
#
# closest pole to real axis: 5.7601632834497405
#
# n= 137
# closest pole to real axis: 7.947283923597225
#
# closest pole to real axis: 5.68186537131844
#
# n= 138
# closest pole to real axis: 7.815742700197096
#
# closest pole to real axis: 5.602952044425312
#
# n= 139
# closest pole to real axis: 7.684031589468417
#
# closest pole to real axis: 5.523446109636303
#
# n= 140
# closest pole to real axis: 7.552154861754925
#
# closest pole to real axis: 5.441090105783256
#
# n= 141
# closest pole to real axis: 7.420117985641666
#
# closest pole to real axis: 5.360536963455448
#
# n= 142
# closest pole to real axis: 7.2879277475763775
#
# closest pole to real axis: 5.279458148725575
#
# n= 143
# closest pole to real axis: 7.155592377189669
#
# closest pole to real axis: 5.1957913773337046
#
# n= 144
# closest pole to real axis: 7.023121678303563
#
# closest pole to real axis: 5.113794302417733
#
# n= 145
# closest pole to real axis: 6.890527164558844
#
# closest pole to real axis: 5.031339618137643
#
# n= 146
# closest pole to real axis: 6.757822198934405
#
# closest pole to real axis: 4.946543339612272
#
# n= 147
# closest pole to real axis: 6.625022135983097
#
# closest pole to real axis: 4.8633015896849905
#
# n= 148
# closest pole to real axis: 6.492144465101858
#
# closest pole to real axis: 4.777871683455618
#
# n= 149
# closest pole to real axis: 6.359208953356118
#
# closest pole to real axis: 4.693929694399035
#
# n= 150
# closest pole to real axis: 6.226237785441959
#
# closest pole to real axis: 4.607946601503282
#
# n= 151
# closest pole to real axis: 6.0932556984389095
#
# closest pole to real axis: 4.523390824259718
#
# n= 152
# closest pole to real axis: 5.960290108449064
#
# closest pole to real axis: 4.4369344758428815
#
# n= 153
# closest pole to real axis: 5.82737122561316
#
# closest pole to real axis: 4.351849867328926
#
# n= 154
# closest pole to real axis: 5.69453215395719
#
# closest pole to real axis: 4.264998405978242
#
# n= 155
# closest pole to real axis: 5.56180897159439
#
# closest pole to real axis: 4.177998452573225
#
# n= 156
# closest pole to real axis: 5.4292407867508725
#
# closest pole to real axis: 4.092295020260158
#
# n= 157
# closest pole to real axis: 5.296869764361489
#
# closest pole to real axis: 4.005008910410083
#
# n= 158
# closest pole to real axis: 5.164741117682466
#
# closest pole to real axis: 3.917623991428058
#
# n= 159
# closest pole to real axis: 5.032903059006258
#
# closest pole to real axis: 3.8301546232412713
#
# n= 160
# closest pole to real axis: 4.9014067031140796
#
# closest pole to real axis: 3.7426139392646776
#
# n= 161
# closest pole to real axis: 4.770305917000203
#
# closest pole to real axis: 3.6550136378003475
#
# n= 162
# closest pole to real axis: 4.639657109158411
#
# closest pole to real axis: 3.5673637591948446
#
# n= 163
# closest pole to real axis: 4.5095189518104535
#
# closest pole to real axis: 3.4796724506775485
#
# n= 164
# closest pole to real axis: 4.379952029571279
#
# closest pole to real axis: 3.391945721830136
#
# n= 165
# closest pole to real axis: 4.251018408504729
#
# closest pole to real axis: 3.304187194844857
#
# n= 166
# closest pole to real axis: 4.122781120165902
#
# closest pole to real axis: 3.215329537446645
#
# n= 167
# closest pole to real axis: 3.9953035563049455
#
# closest pole to real axis: 3.1275404290438855
#
# n= 168
# closest pole to real axis: 3.868648771340265
#
# closest pole to real axis: 3.038707981298004
#
# n= 169
# closest pole to real axis: 3.7428786917318764
#
# closest pole to real axis: 2.950867303474315
#
# n= 170
# closest pole to real axis: 3.618053234098441
#
# closest pole to real axis: 2.8620257845500134
#
# n= 171
# closest pole to real axis: 3.4942293374117352
#
# closest pole to real axis: 2.7731736937678444
#
# n= 172
# closest pole to real axis: 3.3714599191607686
#
# closest pole to real axis: 2.683407526719111
#
# n= 173
# closest pole to real axis: 3.2497927710632295
#
# closest pole to real axis: 2.59450645346003
#
# n= 174
# closest pole to real axis: 3.1292694168982345
#
# closest pole to real axis: 2.504704421784649
#
# n= 175
# closest pole to real axis: 3.0099239632685086
#
# closest pole to real axis: 2.414860728463345
#
# n= 176
# closest pole to real axis: 2.8917819832670473
#
# closest pole to real axis: 2.324947855220893
#
# n= 177
# closest pole to real axis: 2.7748594822313324
#
# closest pole to real axis: 2.234937492408474
#
# n= 178
# closest pole to real axis: 2.659162002221501
#
# closest pole to real axis: 2.144091492999891
#
# n= 179
# closest pole to real axis: 2.54468392430374
#
# closest pole to real axis: 2.052470369238576
#
# n= 180
# closest pole to real axis: 2.4314080197807364
#
# closest pole to real axis: 1.9607945067287713
#
# n= 181
# closest pole to real axis: 2.319305275023106
#
# closest pole to real axis: 1.8690524951840704
#
# n= 182
# closest pole to real axis: 2.2083349581464025
#
# closest pole to real axis: 1.776641523048429
#
# n= 183
# closest pole to real axis: 2.098444795427931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 184
# closest pole to real axis: 1.989570967173025
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 185
# closest pole to real axis: 1.8816374102101747
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 186
# closest pole to real axis: 1.7745536433536562
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 187
# closest pole to real axis: 1.6682100799788377
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 188
# closest pole to real axis: 1.56246972541307
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 189
# closest pole to real axis: 1.457155628213931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 190
# closest pole to real axis: 1.352035165644931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 191
# closest pole to real axis: 1.246806657011942
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 192
# closest pole to real axis: 1.1411043153115208
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 193
# closest pole to real axis: 1.0345624454060312
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 194
# closest pole to real axis: 0.9270356091504948
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 195
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 196
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 197
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 198
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 199
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 200
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 201
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 202
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 203
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 204
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 205
# closest pole to real axis: 0.9270356091504948
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 206
# closest pole to real axis: 1.0345624454060312
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 207
# closest pole to real axis: 1.1411043153115208
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 208
# closest pole to real axis: 1.246806657011942
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 209
# closest pole to real axis: 1.352035165644931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 210
# closest pole to real axis: 1.457155628213931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 211
# closest pole to real axis: 1.56246972541307
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 212
# closest pole to real axis: 1.6682100799788377
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 213
# closest pole to real axis: 1.7745536433536562
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 214
# closest pole to real axis: 1.8816374102101747
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 215
# closest pole to real axis: 1.989570967173025
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 216
# closest pole to real axis: 2.098444795427931
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 217
# closest pole to real axis: 2.2083349581464025
#
# closest pole to real axis: 1.776641523048429
#
# n= 218
# closest pole to real axis: 2.319305275023106
#
# closest pole to real axis: 1.8690524951840704
#
# n= 219
# closest pole to real axis: 2.4314080197807364
#
# closest pole to real axis: 1.9607945067287713
#
# n= 220
# closest pole to real axis: 2.54468392430374
#
# closest pole to real axis: 2.052470369238576
#
# n= 221
# closest pole to real axis: 2.659162002221501
#
# closest pole to real axis: 2.144091492999891
#
# n= 222
# closest pole to real axis: 2.7748594822313324
#
# closest pole to real axis: 2.234937492408474
#
# n= 223
# closest pole to real axis: 2.8917819832670473
#
# closest pole to real axis: 2.324947855220893
#
# n= 224
# closest pole to real axis: 3.0099239632685086
#
# closest pole to real axis: 2.414860728463345
#
# n= 225
# closest pole to real axis: 3.1292694168982345
#
# closest pole to real axis: 2.504704421784649
#
# n= 226
# closest pole to real axis: 3.2497927710632295
#
# closest pole to real axis: 2.59450645346003
#
# n= 227
# closest pole to real axis: 3.3714599191607686
#
# closest pole to real axis: 2.683407526719111
#
# n= 228
# closest pole to real axis: 3.4942293374117352
#
# closest pole to real axis: 2.7731736937678444
#
# n= 229
# closest pole to real axis: 3.618053234098441
#
# closest pole to real axis: 2.8620257845500134
#
# n= 230
# closest pole to real axis: 3.7428786917318764
#
# closest pole to real axis: 2.950867303474315
#
# n= 231
# closest pole to real axis: 3.868648771340265
#
# closest pole to real axis: 3.038707981298004
#
# n= 232
# closest pole to real axis: 3.9953035563049455
#
# closest pole to real axis: 3.1275404290438855
#
# n= 233
# closest pole to real axis: 4.122781120165902
#
# closest pole to real axis: 3.215329537446645
#
# n= 234
# closest pole to real axis: 4.251018408504729
#
# closest pole to real axis: 3.304187194844857
#
# n= 235
# closest pole to real axis: 4.379952029571279
#
# closest pole to real axis: 3.391945721830136
#
# n= 236
# closest pole to real axis: 4.5095189518104535
#
# closest pole to real axis: 3.4796724506775485
#
# n= 237
# closest pole to real axis: 4.639657109158411
#
# closest pole to real axis: 3.5673637591948446
#
# n= 238
# closest pole to real axis: 4.770305917000203
#
# closest pole to real axis: 3.6550136378003475
#
# n= 239
# closest pole to real axis: 4.9014067031140796
#
# closest pole to real axis: 3.7426139392646776
#
# n= 240
# closest pole to real axis: 5.032903059006258
#
# closest pole to real axis: 3.8301546232412713
#
# n= 241
# closest pole to real axis: 5.164741117682466
#
# closest pole to real axis: 3.917623991428058
#
# n= 242
# closest pole to real axis: 5.296869764361489
#
# closest pole to real axis: 4.005008910410083
#
# n= 243
# closest pole to real axis: 5.4292407867508725
#
# closest pole to real axis: 4.092295020260158
#
# n= 244
# closest pole to real axis: 5.56180897159439
#
# closest pole to real axis: 4.177998452573225
#
# n= 245
# closest pole to real axis: 5.69453215395719
#
# closest pole to real axis: 4.264998405978242
#
# n= 246
# closest pole to real axis: 5.82737122561316
#
# closest pole to real axis: 4.351849867328926
#
# n= 247
# closest pole to real axis: 5.960290108449064
#
# closest pole to real axis: 4.4369344758428815
#
# n= 248
# closest pole to real axis: 6.0932556984389095
#
# closest pole to real axis: 4.523390824259718
#
# n= 249
# closest pole to real axis: 6.226237785441959
#
# closest pole to real axis: 4.607946601503282
#
# n= 250
# closest pole to real axis: 6.359208953356118
#
# closest pole to real axis: 4.693929694399035
#
# n= 251
# closest pole to real axis: 6.492144465101858
#
# closest pole to real axis: 4.777871683455618
#
# n= 252
# closest pole to real axis: 6.625022135983097
#
# closest pole to real axis: 4.8633015896849905
#
# n= 253
# closest pole to real axis: 6.757822198934405
#
# closest pole to real axis: 4.946543339612272
#
# n= 254
# closest pole to real axis: 6.890527164558844
#
# closest pole to real axis: 5.031339618137643
#
# n= 255
# closest pole to real axis: 7.023121678303563
#
# closest pole to real axis: 5.113794302417733
#
# n= 256
# closest pole to real axis: 7.155592377189669
#
# closest pole to real axis: 5.1957913773337046
#
# n= 257
# closest pole to real axis: 7.2879277475763775
#
# closest pole to real axis: 5.279458148725575
#
# n= 258
# closest pole to real axis: 7.420117985641666
#
# closest pole to real axis: 5.360536963455448
#
# n= 259
# closest pole to real axis: 7.552154861754925
#
# closest pole to real axis: 5.441090105783256
#
# n= 260
# closest pole to real axis: 7.684031589468417
#
# closest pole to real axis: 5.523446109636303
#
# n= 261
# closest pole to real axis: 7.815742700197096
#
# closest pole to real axis: 5.602952044425312
#
# n= 262
# closest pole to real axis: 7.947283923597225
#
# closest pole to real axis: 5.68186537131844
#
# n= 263
# closest pole to real axis: 8.07865207485694
#
# closest pole to real axis: 5.7601632834497405
#
# n= 264
# closest pole to real axis: 8.209844947735503
#
# closest pole to real axis: 5.840474515760099
#
# n= 265
# closest pole to real axis: 8.340861215082075
#
# closest pole to real axis: 5.917556377058531
#
# n= 266
# closest pole to real axis: 8.471700335428707
#
# closest pole to real axis: 5.993957540202597
#
# n= 267
# closest pole to real axis: 8.602362466443363
#
# closest pole to real axis: 6.06965564457239
#
# n= 268
# closest pole to real axis: 8.732848384597464
#
# closest pole to real axis: 6.147616351191633
#
# n= 269
# closest pole to real axis: 8.86315941120712
#
# closest pole to real axis: 6.221934393373947
#
# n= 270
# closest pole to real axis: 8.993297344321348
#
# closest pole to real axis: 6.295485443721316
#
# n= 271
# closest pole to real axis: 9.123264396062472
#
# closest pole to real axis: 6.368247416613136
#
# n= 272
# closest pole to real axis: 9.25306313614199
#
# closest pole to real axis: 6.440198240821038
#
# n= 273
# closest pole to real axis: 9.382696439343043
#
# closest pole to real axis: 6.51478439921762
#
# n= 274
# closest pole to real axis: 9.512167438632531
#
# closest pole to real axis: 6.585153593885391
#
# n= 275
# closest pole to real axis: 9.641479482529299
#
# closest pole to real axis: 6.65464843703863
#
# n= 276
# closest pole to real axis: 9.770636096424823
#
# closest pole to real axis: 6.72324680948235
#
# n= 277
# closest pole to real axis: 9.899640947966299
#
# closest pole to real axis: 6.790926514699263
#
# n= 278
# closest pole to real axis: 10.028497815998204
#
# closest pole to real axis: 6.857665258612372
#
# n= 279
# closest pole to real axis: 10.157210562776672
#
# closest pole to real axis: 6.927583858077902
#
# n= 280
# closest pole to real axis: 10.285783109330465
#
# closest pole to real axis: 6.992499475529235
#
# n= 281
# closest pole to real axis: 10.414219413110393
#
# closest pole to real axis: 7.056410037354734
#
# n= 282
# closest pole to real axis: 10.542523449211028
#
# closest pole to real axis: 7.119292741246024
#
# n= 283
# closest pole to real axis: 10.670699192503026
#
# closest pole to real axis: 7.1811245837928475
#
# n= 284
# closest pole to real axis: 10.79875060332324
#
# closest pole to real axis: 7.241882338003664
#
# n= 285
# closest pole to real axis: 10.926681614305599
#
# closest pole to real axis: 7.301542530731533
#
# n= 286
# closest pole to real axis: 11.054496118439635
#
# closest pole to real axis: 7.360081419341288
#
# n= 287
# closest pole to real axis: 11.182197960133703
#
# closest pole to real axis: 7.4174749681812555
#
# n= 288
# closest pole to real axis: 11.309790926813124
#
# closest pole to real axis: 7.479094061642277
#
# n= 289
# closest pole to real axis: 11.437278741161482
#
# closest pole to real axis: 7.534284766025162
#
# n= 290
# closest pole to real axis: 11.564665055856105
#
# closest pole to real axis: 7.588260528156159
#
# n= 291
# closest pole to real axis: 11.691953448639037
#
# closest pole to real axis: 7.640996017364049
#
# n= 292
# closest pole to real axis: 11.819147418063384
#
# closest pole to real axis: 7.692465487329583
#
# n= 293
# closest pole to real axis: 11.946250380518025
#
# closest pole to real axis: 7.742642748389067
#
# n= 294
# closest pole to real axis: 12.073265668264014
#
# closest pole to real axis: 7.791501139169997
#
# n= 295
# closest pole to real axis: 12.200196526641378
#
# closest pole to real axis: 7.839013497006911
#
# n= 296
# closest pole to real axis: 12.32704611363946
#
# closest pole to real axis: 7.8851521271186185
#
# n= 297
# closest pole to real axis: 12.453817499323419
#
# closest pole to real axis: 7.929888770975334
#
# n= 298
# closest pole to real axis: 12.580513664926384
#
# closest pole to real axis: 7.973194572722913
#
# n= 299
# closest pole to real axis: 12.707137503204171
#
# closest pole to real axis: 8.022448854991097
#
# n= 300
# closest pole to real axis: 12.833691819323391
#
# closest pole to real axis: 8.063021357139773
#
# n= 301
# closest pole to real axis: 12.960179330978951
#
# closest pole to real axis: 8.102078677627478
#
# n= 302
# closest pole to real axis: 13.086602669305618
#
# closest pole to real axis: 8.139589402721645
#
# n= 303
# closest pole to real axis: 13.212964381191899
#
# closest pole to real axis: 8.175521338765297
#
# n= 304
# closest pole to real axis: 13.33926692940072
#
# closest pole to real axis: 8.209841468035469
#
# n= 305
# closest pole to real axis: 13.465512694531311
#
# closest pole to real axis: 8.242515902140115
#
# n= 306
# closest pole to real axis: 13.591703976467699
#
# closest pole to real axis: 8.273509832768651
#
# n= 307
# closest pole to real axis: 13.717842996619128
#
# closest pole to real axis: 8.302787479607078
#
# n= 308
# closest pole to real axis: 13.843931900080824
#
# closest pole to real axis: 8.330312034721176
#
# n= 309
# closest pole to real axis: 13.969972755972108
#
# closest pole to real axis: 8.356045603458009
#
# n= 310
# closest pole to real axis: 14.095967560068534
#
# closest pole to real axis: 8.379949141781301
#
# n= 311
# closest pole to real axis: 14.221918238083544
#
# closest pole to real axis: 8.40198238900508
#
# n= 312
# closest pole to real axis: 14.347826646014259
#
# closest pole to real axis: 8.42210379599676
#
# n= 313
# closest pole to real axis: 14.473694572243803
#
# closest pole to real axis: 8.440270448332688
#
# n= 314
# closest pole to real axis: 14.599523741121581
#
# closest pole to real axis: 8.456437983904479
#
# n= 315
# closest pole to real axis: 14.725315813607688
#
# closest pole to real axis: 8.470560504418028
#
# n= 316
# closest pole to real axis: 14.85107238781052
#
# closest pole to real axis: 8.482590479652186
#
# n= 317
# closest pole to real axis: 14.976795004818237
#
# closest pole to real axis: 8.49247864502488
#
# n= 318
# closest pole to real axis: 15.1024851470785
#
# closest pole to real axis: 8.51294306676737
#
# n= 319
# closest pole to real axis: 15.228144241991197
#
# closest pole to real axis: 8.51877002727897
#
# n= 320
# closest pole to real axis: 15.353773663754854
#
# closest pole to real axis: 8.522308005340719
#
# n= 321
# closest pole to real axis: 15.47937473505292
#
# closest pole to real axis: 8.52350013286289
#
# n= 322
# closest pole to real axis: 15.604948727440373
#
# closest pole to real axis: 8.522287187583034
#
# n= 323
# closest pole to real axis: 15.730496863973503
#
# closest pole to real axis: 8.518607429184039
#
# n= 324
# closest pole to real axis: 15.856020324464975
#
# closest pole to real axis: 8.512396420622727
#
# n= 325
# closest pole to real axis: 15.981520240309015
#
# closest pole to real axis: 8.503586831760092
#
# n= 326
# closest pole to real axis: 16.106997701972258
#
# closest pole to real axis: 8.49210822542645
#
# n= 327
# closest pole to real axis: 16.232453756596858
#
# closest pole to real axis: 8.477886821632326
#
# n= 328
# closest pole to real axis: 16.35788941258549
#
# closest pole to real axis: 8.46084523877235
#
# n= 329
# closest pole to real axis: 16.48330563932174
#
# closest pole to real axis: 8.440902207161288
#
# n= 330
# closest pole to real axis: 16.60870336775248
#
# closest pole to real axis: 8.417972253153888
#
# n= 331
# closest pole to real axis: 16.734083495724835
#
# closest pole to real axis: 8.391965349567382
#
# n= 332
# closest pole to real axis: 16.85944688452693
#
# closest pole to real axis: 8.362786524956595
#
# n= 333
# closest pole to real axis: 16.984794361716986
#
# closest pole to real axis: 8.330335430273852
#
# n= 334
# closest pole to real axis: 17.110126726663193
#
# closest pole to real axis: 8.294505853903004
#
# n= 335
# closest pole to real axis: 17.235444742746044
#
# closest pole to real axis: 8.255185177848674
#
# n= 336
# closest pole to real axis: 17.360749147446292
#
# closest pole to real axis: 8.212253765872868
#
# n= 337
# closest pole to real axis: 17.486040649932903
#
# closest pole to real axis: 8.165584273844004
#
# n= 338
# closest pole to real axis: 17.611319929696947
#
# closest pole to real axis: 8.115040867981168
#
# n= 339
# closest pole to real axis: 17.736587641867132
#
# closest pole to real axis: 8.06047833728814
#
# n= 340
# closest pole to real axis: 17.86184441696973
#
# closest pole to real axis: 8.001741079568227
#
# n= 341
# closest pole to real axis: 17.98709085831265
#
# closest pole to real axis: 7.9386619396507205
#
# n= 342
# closest pole to real axis: 18.112327548578406
#
# closest pole to real axis: 7.871060873737573
#
# n= 343
# closest pole to real axis: 18.237555048594988
#
# closest pole to real axis: 7.798743402352756
#
# n= 344
# closest pole to real axis: 18.362773894885315
#
# closest pole to real axis: 7.7214988128086475
#
# n= 345
# closest pole to real axis: 18.487984604406222
#
# closest pole to real axis: 7.639098058488148
#
# n= 346
# closest pole to real axis: 18.61318767689303
#
# closest pole to real axis: 7.551291290499664
#
# n= 347
# closest pole to real axis: 18.738383588495154
#
# closest pole to real axis: 7.457804931958106
#
# n= 348
# closest pole to real axis: 18.863572799816698
#
# closest pole to real axis: 7.358338199922567
#
# n= 349
# closest pole to real axis: 18.988755753464236
#
# closest pole to real axis: 7.252558927613034
#
# n= 350
# closest pole to real axis: 19.113932875034596
#
# closest pole to real axis: 7.140098510704329
#
# n= 351
# closest pole to real axis: 19.23910457507712
#
# closest pole to real axis: 7.0205457417410075
#
# n= 352
# closest pole to real axis: 19.364271246757813
#
# closest pole to real axis: 6.893439213555331
#
# n= 353
# closest pole to real axis: 19.48943326474402
#
# closest pole to real axis: 6.758257863683417
#
# n= 354
# closest pole to real axis: 19.614590999204218
#
# closest pole to real axis: 6.6571961371517645
#
# n= 355
# closest pole to real axis: 19.739744797166633
#
# closest pole to real axis: 6.5060668759676235
#
# n= 356
# closest pole to real axis: 19.864894996384162
#
# closest pole to real axis: 6.344999077955476
#
# n= 357
# closest pole to real axis: 19.990041921317058
#
# closest pole to real axis: 6.173108549575553
#
# n= 358
# closest pole to real axis: 20.115185886366714
#
# closest pole to real axis: 5.98935329669576
#
# n= 359
# closest pole to real axis: 20.240327188404194
#
# closest pole to real axis: 5.792489563937006
#
# n= 360
# closest pole to real axis: 20.36546612019163
#
# closest pole to real axis: 5.581010564005701
#
# n= 361
# closest pole to real axis: 20.490602954058474
#
# closest pole to real axis: 5.353058733326027
#
# n= 362
# closest pole to real axis: 20.615737966911823
#
# closest pole to real axis: 5.106295899881388
#
# n= 363
# closest pole to real axis: 20.74087140689665
#
# closest pole to real axis: 4.837703633073977
#
# n= 364
# closest pole to real axis: 20.866003530736766
#
# closest pole to real axis: 4.543261257947291
#
# n= 365
# closest pole to real axis: 20.991134571677378
#
# closest pole to real axis: 4.2173946781181195
#
# n= 366
# closest pole to real axis: 21.116264765546937
#
# closest pole to real axis: 3.8519571625859848
#
# n= 367
# closest pole to real axis: 21.241394326962457
#
# closest pole to real axis: 3.434136767830813
#
# n= 368
# closest pole to real axis: 21.36652347577744
#
# closest pole to real axis: 2.9414584443137364
#
# n= 369
# closest pole to real axis: 21.4916524148475
#
# closest pole to real axis: 2.32654438045448
#
# n= 370
# closest pole to real axis: 21.616781342081584
#
# closest pole to real axis: 1.4400581159630406
#
# n= 371
# closest pole to real axis: 21.74191045595569
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 372
# closest pole to real axis: 21.86703992763445
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 373
# closest pole to real axis: 21.992169942135465
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 374
# closest pole to real axis: 22.1173006690936
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 375
# closest pole to real axis: 22.24243227681319
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 376
# closest pole to real axis: 22.367564926130456
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 377
# closest pole to real axis: 22.492698762517588
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 378
# closest pole to real axis: 22.61783393543877
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 379
# closest pole to real axis: 22.7429705955975
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 380
# closest pole to real axis: 22.868108873647852
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 381
# closest pole to real axis: 22.993248908108143
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 382
# closest pole to real axis: 23.11839082412052
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 383
# closest pole to real axis: 23.243534747770205
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 384
# closest pole to real axis: 23.36868079489247
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 385
# closest pole to real axis: 23.493829090661126
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 386
# closest pole to real axis: 23.618979737699753
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 387
# closest pole to real axis: 23.744132853094126
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 388
# closest pole to real axis: 23.869288533669813
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 389
# closest pole to real axis: 23.994446889472595
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 390
# closest pole to real axis: 24.11960801229606
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 391
# closest pole to real axis: 24.24477199890277
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 392
# closest pole to real axis: 24.36993894431013
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 393
# closest pole to real axis: 24.495108928627065
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 394
# closest pole to real axis: 24.62028205205319
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 395
# closest pole to real axis: 24.745458396225118
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 396
# closest pole to real axis: 24.870638033161168
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 397
# closest pole to real axis: 24.99582105416153
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 398
# closest pole to real axis: 25.12100752558248
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA
#
# n= 399
# closest pole to real axis: 25.2461975237689
#
# closest pole to real axis: 0.0
#
# Cannot find suitable pole-free interpolation, Return naive AAA

# %%
fig, ax = plt.subplots(5, 2, figsize=(10, 25), sharex=False, sharey=False)

for i in range(wn.size):
    ax[0,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0].imag, 'C0')
    ax[0,0].plot(t_values_ED.real, G00_interp[:, i].imag, 'C1--')
ax[0,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0].imag, 'C0', label = 'True')
ax[0,0].plot(t_values_ED.real, G00_interp[:, i].imag, 'C1--', label = 'AAA')
ax[0,0].set_ylim([-2,2])
ax[0,0].set_xlim([0,2])
ax[0,0].set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%U)
ax[0,0].legend()

for i in range(wn.size):
    ax[1,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[1,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--')
ax[1,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[1,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--', label = 'AAA')
ax[1,0].set_ylim([-2,8])
ax[1,0].set_xlim([0,2])
ax[1,0].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[1,0].legend()

wn_id = [Nw, Nw-1, Nw-2, Nw-3, Nw-4]
for i in wn_id:
    print("frequency =", wn[i])
    ax[2,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0 ].imag, 'C0')
    ax[2,0].plot(t_values_ED.real, G00_interp[:, i].imag, 'C1--')
ax[2,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0 ].imag, 'C0', label = 'True')
ax[2,0].plot(t_values_ED.real, G00_interp[:, i].imag, 'C1--', label = 'AAA')
ax[2,0].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[2,0].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[2,0].set_ylim([-2,3])
ax[2,0].set_xlim([0,2])
ax[2,0].set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%U)
ax[2,0].legend()

for i in wn_id:
    ax[3,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[3,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--')
ax[3,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[3,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--', label = 'AAA')
ax[3,0].plot(1/7+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[3,0].plot(1/10+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[3,0].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[3,0].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[3,0].set_ylim([-2,2])
ax[3,0].set_xlim([0,2])
ax[3,0].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[3,0].legend()

wn_id = [Nw-5, Nw-6, Nw-7, Nw-8, Nw-9, Nw-10, Nw-15, Nw-20, Nw-25, Nw-30]

print("\n")
for i in wn_id:
    print("frequency =", wn[i])
    ax[4,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[4,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--')
ax[4,0].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[4,0].plot(t_values_ED.real, G01_interp[:, i].real, 'C1--', label = 'AAA')
ax[4,0].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[4,0].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[4,0].plot(1/7+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[4,0].plot(1/10+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[4,0].set_ylim([-2,2])
ax[4,0].set_xlim([0,2])
ax[4,0].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[4,0].legend()
#############################################################
for i in range(wn.size):
    ax[0,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0].imag, 'C0')
    ax[0,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,0].imag, 'C1--')
ax[0,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0].imag, 'C0', label = 'True')
ax[0,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,0].imag, 'C1--', label = 'wce')
ax[0,1].set_ylim([-2,2])
ax[0,1].set_xlim([0,2])
ax[0,1].set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%U)
ax[0,1].legend()

for i in range(wn.size):
    ax[1,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[1,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--')
ax[1,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[1,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--', label = 'wce')
ax[1,1].set_ylim([-2,8])
ax[1,1].set_xlim([0,2])
ax[1,1].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[1,1].legend()

wn_id = [Nw, Nw-1, Nw-2, Nw-3, Nw-4]
for i in wn_id:
    ax[2,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0 ].imag, 'C0')
    ax[2,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,0].imag, 'C1--')
ax[2,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,0 ].imag, 'C0', label = 'True')
ax[2,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,0].imag, 'C1--', label = 'wce')
ax[2,1].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[2,1].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[2,1].set_ylim([-2,3])
ax[2,1].set_xlim([0,2])
ax[2,1].set_title(r'$Im[G_{00}(i\omega_n,U=%.1f, t)]$'%U)
ax[2,1].legend()

for i in wn_id:
    ax[3,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[3,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--')
ax[3,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[3,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--', label = 'wce')
ax[3,1].plot(1/7+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[3,1].plot(1/10+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[3,1].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[3,1].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[3,1].set_ylim([-2,8])
ax[3,1].set_xlim([0,2])
ax[3,1].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[3,1].legend()

wn_id = [Nw-5, Nw-6, Nw-7, Nw-8, Nw-9, Nw-10, Nw-15, Nw-20, Nw-25, Nw-30]

print("\n")
for i in wn_id:
    ax[4,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0')
    ax[4,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--')
ax[4,1].plot(t_values_ED.real, Gij_iwn_exact_real[:, i, 0,1 ].real, 'C0', label = 'True')
ax[4,1].plot(t_values_ED.real, Gij_iwn_wce[interp_order, :, i, 0,1].real, 'C1--', label = 'wce')
ax[4,1].plot(T_wce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'k--')
ax[4,1].plot(T_sce+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'r--')
ax[4,1].plot(1/7+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[4,1].plot(1/10+0*t_values_ED.real, np.linspace(-10,10,t_values_ED.size), 'g--')
ax[4,1].set_ylim([-2,2])
ax[4,1].set_xlim([0,2])
ax[4,1].set_title(r'$Re[G_{01}(i\omega_n,U=%.1f, t)]$'%U)
ax[4,1].legend()
# Out:
# frequency = 0.06283185307179587
# frequency = -0.06283185307179587
# frequency = -0.18849555921538758
# frequency = -0.3141592653589793
# frequency = -0.43982297150257105
#
#
# frequency = -0.5654866776461628
# frequency = -0.6911503837897545
# frequency = -0.8168140899333463
# frequency = -0.9424777960769378
# frequency = -1.0681415022205298
# frequency = -1.1938052083641213
# frequency = -1.8221237390820801
# frequency = -2.4504422698000385
# frequency = -3.078760800517997
# frequency = -3.707079331235956

# %%
plt.figure(1)
for i in range(wn.size):
    plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, i, 0,0]-G00_interp[:, i]), 'C0', label = 'AAA')
plt.semilogy(t_values_ED.real, 1e-2+0*t_values_ED.real, 'k--')
plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, Nw, 0,0]-G00_interp[:, Nw]), 'r*')
plt.semilogy(1/7+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.semilogy(1/10+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.ylim([1e-5,1])
plt.xlabel(r"$t$")
plt.title(r'$Im[E_{00}(i\omega_n,U=%.1f, t)]$'%U)

plt.figure(2)
for i in range(wn.size):
    plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, i, 0,1 ]-G01_interp[:, i]), label = 'AAA')
plt.semilogy(t_values_ED.real, 1e-1+0*t_values_ED.real, 'k--')
plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, Nw, 0,1 ]-G01_interp[:, Nw]), 'r*', label = 'AAA')
plt.semilogy(1/7+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.semilogy(1/10+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.ylim([1e-5, 10])
plt.xlabel(r"$t$")
plt.title(r'$Re[E_{01}(i\omega_n,U=%.1f, t)]$'%U)

plt.figure(3)
for i in wn_id:
    plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, i, 0,0]-G00_interp[:, i]), 'C0', label = 'AAA')
plt.semilogy(t_values_ED.real, 1e-2+0*t_values_ED.real, 'k--')
plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, Nw, 0,0]-G00_interp[:, Nw]), 'r*')
plt.semilogy(1/7+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.semilogy(1/10+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.ylim([1e-5,1])
plt.xlabel(r"$t$")
plt.title(r'$Im[E_{00}(i\omega_n,U=%.1f, t)]$'%U)

plt.figure(4)
for i in wn_id:
    plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, i, 0,1 ]-G01_interp[:, i]), 'C0', label = 'AAA')
plt.semilogy(t_values_ED.real, 1e-1+0*t_values_ED.real, 'k--')
plt.semilogy(t_values_ED.real, np.abs(Gij_iwn_exact_real[:, Nw, 0,1 ]-G01_interp[:, Nw]), 'r*', label = 'AAA')
plt.semilogy(1/7+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.semilogy(1/10+0*t_values_ED.real, np.linspace(0,1,t_values_ED.size), 'g--')
plt.ylim([1e-5, 1])
plt.xlabel(r"$t$")
plt.title(r'$Re[E_{01}(i\omega_n,U=%.1f, t)]$'%U)
# Out:
# Text(0.5, 1.0, '$Re[E_{01}(i\\omega_n,U=1.0, t)]$')

# %%
print("This runs")
raise SystemExit

Ed_end = int(Nt/2)
Ed_gap = int(Nt/50)

tau = np.linspace(0,beta,Ntau)
Test_t = t_values_ED[0:Ed_end:Ed_gap]

print('The test ts are: ', Test_t)
G01_iwn_exact_CG = Gij_iwn_exact[0:Ed_end:Ed_gap,:,0,1]
G00_iwn_exact_CG = Gij_iwn_exact[0:Ed_end:Ed_gap,:,0,0]
G01_iwn_interp_CG = G01_interp[0:Ed_end:Ed_gap, :]
G00_iwn_interp_CG = G00_interp[0:Ed_end:Ed_gap, :]

    

Gij_iwn_exact_CG = np.zeros((len(Test_t), wn.size, Ns, Ns), dtype ='complex')
Gij_iwn_interp_CG = np.zeros((len(Test_t), wn.size, Ns, Ns), dtype ='complex')

Gij_iwn_interp_CG[:, :, 1, 1] = G00_iwn_interp_CG
Gij_iwn_interp_CG[:, :, 1, 0] = G01_iwn_interp_CG
Gij_iwn_interp_CG[:, :, 0, 0] = G00_iwn_interp_CG
Gij_iwn_interp_CG[:, :, 0, 1] = G01_iwn_interp_CG


Gij_iwn_exact_CG[:, :, 1, 1] = G00_iwn_exact_CG
Gij_iwn_exact_CG[:, :, 1, 0] = G01_iwn_exact_CG
Gij_iwn_exact_CG[:, :, 0, 0] = G00_iwn_exact_CG
Gij_iwn_exact_CG[:, :, 0, 1] = G01_iwn_exact_CG



Gij_iwn_interp_proj = np.zeros((len(Test_t), wn.size, Ns, Ns), dtype='complex')
for u in range(len(Test_t)):
    print("t value is", Test_t[u])
    func_NN, _, _, _ = anacont(Gij_iwn_interp_CG[u], 1j*wn, tol = 0.1)
    Gij_iwn_interp_temp = func_NN(1j*wn)
    Gij_iwn_interp_proj[u] = Gij_iwn_interp_temp



Gij_tau_exact_CG = np.zeros((len(Test_t), Ntau, Ns, Ns))
Gij_tau_interp_CG = np.zeros((len(Test_t), Ntau, Ns, Ns))
Gij_tau_interp_proj = np.zeros((len(Test_t), Ntau, Ns, Ns))

for i in range(len(Test_t)):
    Gij_tau_exact_CG[i] = np.real(ut.Gij_iwn_to_Gij_tau(Gij_iwn_exact_CG[i], wn, tau, beta))
    Gij_tau_interp_CG[i] = np.real(ut.Gij_iwn_to_Gij_tau(Gij_iwn_interp_CG[i], wn, tau, beta))
    Gij_tau_interp_proj[i] = np.real(ut.Gij_iwn_to_Gij_tau(Gij_iwn_interp_proj[i], wn, tau, beta))
# Out:
# This runs
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /global/common/software/nersc/pe/conda-envs/26.1.0/python-3.13/nersc-python/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3709: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
l=0
fig,ax = plt.subplots(4,int(Test_t.size/4),figsize=(40,40),sharex=True,sharey=True)
for i in np.arange(4):
    for j in np.arange(int(Test_t.size/4)):
        ax[i,j].plot(wn, G00_iwn_exact_CG[l,:].imag, label = r'Analytic')
        ax[i,j].plot(wn, G00_iwn_interp_CG[l,:].imag, '--', label = r'AAA_order=%d'%interp_order)
        ax[i,j].plot(wn, Gij_iwn_interp_proj[l,:, 0, 0].imag, '-.', label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([-1,2])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real), fontsize =20)
        ax[i,j].set_xlabel(r'$\omega_n$', fontsize =20)
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(i\omega_n)$'%(0,0), fontsize =20)
        ax[i,j].legend(frameon= False, fontsize =20)
        l = l+1

# %%
l=0
fig,ax = plt.subplots(4,int(Test_t.size/4),figsize=(40,40),sharex=True,sharey=True)
for i in np.arange(4):
    for j in np.arange(int(Test_t.size/4)):
        ax[i,j].plot(wn, G01_iwn_exact_CG[l,:].real, label = r'Analytic')
        ax[i,j].plot(wn, G01_iwn_interp_CG[l,:].real, '--',  label = r'AAA-order=%d'%interp_order)
        ax[i,j].plot(wn, Gij_iwn_interp_proj[l,:, 0, 1].real, '-.', label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([-2,2])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real), fontsize =20)
        ax[i,j].set_xlabel(r'$\omega_n$', fontsize =20)
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(i\omega_n)$'%(0,1), fontsize =20)
        ax[i,j].legend(frameon= False, fontsize = 20)
        l = l+1

# %%
l=0
fig,ax = plt.subplots(2,int(Test_t.size/2),figsize=(20,10),sharex=True,sharey=True)
for i in np.arange(2):
    for j in np.arange(int(Test_t.size/2)):
        ax[i,j].plot(tau, -Gij_tau_exact_CG[l,:, 0, 0], label = r'Analytic')
        ax[i,j].plot(tau, -Gij_tau_interp_CG[l,:, 0, 0], '--', label = r'AAA-order=%d'%interp_order)
        # ax[i,j].plot(tau, -Gij_tau_interp_proj[l,:, 0, 0], '-.', label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([0,1])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real))
        ax[i,j].set_xlabel(r'$\tau$')
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(\tau)$'%(0,0))
        ax[i,j].legend(frameon= False)
        l = l+1
        
l=0
fig,ax = plt.subplots(2,int(Test_t.size/2),figsize=(20,10),sharex=True,sharey=True)
for i in np.arange(2):
    for j in np.arange(int(Test_t.size/2)):
        ax[i,j].plot(tau, -Gij_tau_exact_CG[l,:, 0, 1], label = r'Analytic')
        ax[i,j].plot(tau, -Gij_tau_interp_CG[l,:, 0, 1], '--', label = r'AAA-order=%d'%interp_order)
        # ax[i,j].plot(tau, -Gij_tau_interp_proj[l,:, 0, 1], '-.', label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([-1,1])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real))
        ax[i,j].set_xlabel(r'$\tau$')
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(\tau)$'%(0,1))
        ax[i,j].legend(frameon= False)
        l = l+1

# %%
l=0
fig,ax = plt.subplots(2,int(Test_t.size/2),figsize=(20,10),sharex=True,sharey=True)
for i in np.arange(2):
    for j in np.arange(int(Test_t.size/2)):
        ax[i,j].semilogy(tau, -Gij_tau_exact_CG[l,:, 0, 0].real, label = r'Analytic')
        ax[i,j].semilogy(tau, -Gij_tau_interp_CG[l,:, 0, 0], '--', label = r'AAA-order=%d'%interp_order)
        ax[i,j].semilogy(tau, -Gij_tau_interp_proj[l,:, 0, 0].real, '-.', label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([1e-5, 1])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real))
        ax[i,j].set_xlabel(r'$\tau$')
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(\tau)$'%(0,0))
        ax[i,j].legend(frameon= False)
        l = l+1

# %%
l=0
fig,ax = plt.subplots(2,int(Test_t.size/2),figsize=(20,10),sharex=True,sharey=True)
for i in np.arange(2):
    for j in np.arange(int(Test_t.size/2)):
        ax[i,j].semilogy(tau, np.abs(Gij_tau_interp_proj[l,:, 0, 0]-Gij_tau_exact_CG[l,:, 0, 0]), label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].semilogy(tau, np.abs(Gij_tau_interp_CG[l,:, 0, 0]-Gij_tau_exact_CG[l,:, 0, 0]), '--', label = r'AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([1e-5, 1])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real))
        ax[i,j].set_xlabel(r'$\tau$')
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(\tau)$'%(0,0))
        ax[i,j].legend(frameon= False)
        l = l+1

l=0
fig,ax = plt.subplots(2,int(Test_t.size/2),figsize=(20,10),sharex=True,sharey=True)
for i in np.arange(2):
    for j in np.arange(int(Test_t.size/2)):
        ax[i,j].semilogy(tau, np.abs(Gij_tau_interp_proj[l,:, 0, 1]-Gij_tau_exact_CG[l,:, 0, 1]), label = r'Proj, AAA-order=%d'%interp_order)
        ax[i,j].semilogy(tau, np.abs(Gij_tau_interp_CG[l,:, 0, 1]-Gij_tau_exact_CG[l,:, 0, 1]), '--', label = r'AAA-order=%d'%interp_order)
        ax[i,j].set_ylim([1e-5, 1])
        ax[i,j].set_title(r'$t=%.2f$'%(Test_t[l].real))
        ax[i,j].set_xlabel(r'$\tau$')
        ax[i,j].set_ylabel(r'$-G_{%d%d}^M(\tau)$'%(0,1))
        ax[i,j].legend(frameon= False)
        l = l+1
